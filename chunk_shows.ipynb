# %%
#from chunk_mp3 import detect_silence_ranges, refine_boundaries_with_librosa, split_audio_combined
from double_chunk_mp3 import chunk_audio, process_chunk, split_audio_with_chunks
import os

# %%
music_dir = '/Users/joe/Music'

# %%
orig_dir = music_dir + '/Billy Strings/billystrings2024-09—Frost-Amphitheater'

# %%
big_file = orig_dir + '/BillyStrings-Frost.mp3'

# %%
output_directory = orig_dir

# %%
big_mp3 = big_file  # Replace with your large MP3 file path
output_directory = orig_dir  # Directory to save the output segments
split_audio_with_chunks(big_mp3, output_directory, chunk_size=10 * 60 * 1000, min_silence_len=2000, silence_thresh=-20)
# Out:
# Audio split into 16 chunks of approximately 10.0 minutes each.
# Processing chunk 1/16, start time: 0ms
# Detected 4 nonsilent segments in this chunk.
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_79257_240821.mp3
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_268252_583884.mp3
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_586009_592079.mp3
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_594377_600000.mp3
# Processing chunk 2/16, start time: 600000ms
# Detected 15 nonsilent segments in this chunk.
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_600000_819960.mp3
# Saved segment: /Users/joe/Music/Billy Strings/billystrings2024-09—Frost-Amphitheater/segment_825446_828846.mp3
# ...

# %%
'''
big_mp3 = "large_audio_file.mp3"
output_directory = "output_songs_combined"
split_audio_combined(big_mp3, output_directory, min_silence_len=1000, silence_thresh=-40)
'''
# Out:
# '\nbig_mp3 = "large_audio_file.mp3"\noutput_directory = "output_songs_combined"\nsplit_audio_combined(big_mp3, output_directory, min_silence_len=1000, silence_thresh=-40)\n'
